# %%
from pathlib import Path
import json, textwrap, os, sys

# %%
LAB_ROOT = Path(r"C:\Users\krith\OneDrive\TCS_trainings\MLOps\Specialization_coursera")
SRC = LAB_ROOT / "src" / "devops_ml_lab"
TESTS = LAB_ROOT / "tests"
DATA = LAB_ROOT / "data" / "raw"
MODELS = LAB_ROOT / "models"
REPORTS = LAB_ROOT / "reports"
WORKFLOWS = LAB_ROOT / ".github" / "workflows"

for p in [SRC, TESTS, DATA, MODELS, REPORTS, WORKFLOWS]:
    p.mkdir(parents=True, exist_ok=True)

(SRC / "__init__.py").write_text("")
print(f"lab workspace ready at: {LAB_ROOT.resolve()}")
# Out:
# lab workspace ready at: C:\Users\krith\OneDrive\TCS_trainings\MLOps\Specialization_coursera

# %%
# creating the git readme and .gitignore files

(LAB_ROOT / "README.md").write_text('''# DevOps for ML lab workspace

This project demonstrates a complete ML engineering workflow:
1. Generate data
2. Validate data
3. Test code and data assumptions
4. Train model
5. Serve model through FastAPI
6. Package with Docker
''')

(LAB_ROOT / ".gitignore").write_text('''.venv/
__pycache__/
.ipynb_checkpoints/
data/raw/*.csv
models/*.joblib
reports/*.json
reports/*.md
''')

print((LAB_ROOT / "README.md").read_text())
print("#n.gitignore created with ML artifact exclusions.")
# Out:
# # DevOps for ML lab workspace
#
# This project demonstrates a complete ML engineering workflow:
# 1. Generate data
# 2. Validate data
# 3. Test code and data assumptions
# 4. Train model
# 5. Serve model through FastAPI
# 6. Package with Docker
#
# #n.gitignore created with ML artifact exclusions.
